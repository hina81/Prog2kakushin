# %% [markdown]
# <a href="https://colab.research.google.com/github/hina81/Prog2kakushin/blob/main/work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 固定電話番号から住所検索

# %%
num = int(input('番号の上6桁を入力：'))
# Out:
# 番号の上6桁を入力：084934

# %%
import pandas as pd
import csv


df = pd.read_csv('市外局番.csv')
area_code = str(num)[:2]
print(area_code)
df
# Out:
# 84
#                                    番号区画   市外局番 市内局番
# 0                北海道江別市、札幌市、北広島市、空知郡南幌町   11.0  CDE
# 1                            北海道恵庭市、千歳市  123.0   DE
# 2                        北海道夕張市（富野を除く。）  123.0   DE
# 3                          北海道夕張市富野、夕張郡  123.0   DE
# 4                                北海道芦別市  124.0   DE
# ..                                  ...    ...  ...
# 581   鹿児島県奄美市、大島郡（宇検村、喜界町、龍郷町及び大和村に限る。）  997.0   DE
# 582  鹿児島県大島郡（宇検村、喜界町、瀬戸内町、龍郷町及び大和村を除く。）  997.0   DE
# 583              鹿児島県西之表市、熊毛郡（屋久島町を除く。）  997.0   DE
# 584                         鹿児島県熊毛郡屋久島町  997.0   DE
# 585                         鹿児島県大島郡瀬戸内町  997.0   DE
#
# [586 rows x 3 columns]

# %%
df['市外局番'] = pd.to_numeric(df['市外局番'], errors='coerce').fillna(0).astype('int')


df['市外局番'] = df['市外局番'].astype(str)
itti = df['市外局番'].str.contains(area_code)

address = itti.iloc['番号区画'][itti]

#print(address)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-6538a59b0df0> in <cell line: 7>()
#       5 itti = df['市外局番'].str.contains(area_code)
#       6
# ----> 7 address = itti.iloc['番号区画']
#       8
#       9 #print(address)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1620             key = item_from_zerodim(key)
#    1621             if not is_integer(key):
# -> 1622                 raise TypeError("Cannot index by location index with a non-integer key")
#    1623
# ...
